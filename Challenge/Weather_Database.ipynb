# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime
import time

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Starting URL for Weather Map API Call.
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ff0ac872ee548d4e465ee0a26b2803c2

# %%
# Create an endpoint URL for a city.
city_url = url + '&q=' + 'tasiilaq'
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ff0ac872ee548d4e465ee0a26b2803c2&q=tasiilaq

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 593

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print('Beginning Data Retrieval     ')
print('-----------------------------')

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + '&q=' + city

    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_weather_descrip = city_weather['weather'][0]['description']
        city_rain = 0
        if 'rain' in city_weather_descrip: 
            try:
                city_rain = city_weather['rain']['3h']
            except:
                print('No rainfall data. Setting to 0in')
        
        city_snow = 0
        if 'snow' in city_weather_descrip:
            try:
                city_snow = city_weather['snow']['3h']
            except:
                print('No snowfall data. Setting to 0in')
       
        city_country = city_weather['sys']['country']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({'City': city.title(),
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Weather Description': city_weather_descrip,
                          'Rainfall in. (last 3 hrs.)': city_rain,
                          'Snowfall in. (last 3 hrs.)': city_snow,
                          'Country': city_country,
                          'Date': city_date})

    # If an error is experienced, skip the city.
    except:
        print('City not found. Skipping...')
        pass

# Indicate that Data Loading is complete.
print('-----------------------------')
print('Data Retrieval Complete      ')
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | guerrero negro
# Processing Record 2 of Set 1 | fare
# Processing Record 3 of Set 1 | ahipara
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 1 | bambous virieux
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | mar del plata
# Processing Record 9 of Set 1 | norman wells
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | pangnirtung
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | egvekinot
# Processing Record 14 of Set 1 | chernyshevskiy
# Processing Record 15 of Set 1 | escanaba
# Processing Record 16 of Set 1 | taksimo
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | kawalu
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | ugoofaaru
# Processing Record 23 of Set 1 | zlobin
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | longyearbyen
# No snowfall data. Setting to 0in
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 1 | bethel
# Processing Record 31 of Set 1 | fortuna
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | pundaguitan
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | avera
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | meadow lake
# No snowfall data. Setting to 0in
# Processing Record 39 of Set 1 | mahebourg
# Processing Record 40 of Set 1 | sechura
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | millau
# Processing Record 43 of Set 1 | havre-saint-pierre
# Processing Record 44 of Set 1 | sioux lookout
# No snowfall data. Setting to 0in
# Processing Record 45 of Set 1 | aklavik
# No snowfall data. Setting to 0in
# Processing Record 46 of Set 1 | chiria
# Processing Record 47 of Set 1 | kargil
# Processing Record 48 of Set 1 | sao domingos
# Processing Record 49 of Set 1 | kamaishi
# Processing Record 50 of Set 1 | ushuaia
# No rainfall data. Setting to 0in
# Processing Record 1 of Set 2 | nuuk
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | mut
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | sembakung
# Processing Record 7 of Set 2 | naze
# Processing Record 8 of Set 2 | altay
# Processing Record 9 of Set 2 | kinshasa
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | punta gorda
# No rainfall data. Setting to 0in
# Processing Record 12 of Set 2 | sale
# Processing Record 13 of Set 2 | nikolskoye
# Processing Record 14 of Set 2 | karratha
# Processing Record 15 of Set 2 | tuktoyaktuk
# No snowfall data. Setting to 0in
# Processing Record 16 of Set 2 | diamantino
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | uppsala
# Processing Record 19 of Set 2 | chuy
# Processing Record 20 of Set 2 | albany
# No rainfall data. Setting to 0in
# Processing Record 21 of Set 2 | berdigestyakh
# Processing Record 22 of Set 2 | tanabe
# Processing Record 23 of Set 2 | vila franca do campo
# Processing Record 24 of Set 2 | ancud
# Processing Record 25 of Set 2 | belle fourche
# Processing Record 26 of Set 2 | te anau
# Processing Record 27 of Set 2 | port-de-paix
# City not found. Skipping...
# Processing Record 28 of Set 2 | oistins
# No rainfall data. Setting to 0in
# Processing Record 29 of Set 2 | tomatlan
# Processing Record 30 of Set 2 | yenotayevka
# Processing Record 31 of Set 2 | bathsheba
# No rainfall data. Setting to 0in
# Processing Record 32 of Set 2 | udachnyy
# No snowfall data. Setting to 0in
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | kununurra
# Processing Record 35 of Set 2 | salalah
# Processing Record 36 of Set 2 | teeli
# Processing Record 37 of Set 2 | poum
# Processing Record 38 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 2 | bryan
# Processing Record 41 of Set 2 | mayskiy
# Processing Record 42 of Set 2 | dudinka
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | kukushtan
# No snowfall data. Setting to 0in
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | sorong
# Processing Record 47 of Set 2 | chifeng
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | mataura
# Processing Record 50 of Set 2 | kavaratti
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | sao filipe
# Processing Record 3 of Set 3 | namibe
# Processing Record 4 of Set 3 | ryotsu
# Processing Record 5 of Set 3 | fort nelson
# No snowfall data. Setting to 0in
# Processing Record 6 of Set 3 | eyl
# Processing Record 7 of Set 3 | shingu
# Processing Record 8 of Set 3 | bredasdorp
# Processing Record 9 of Set 3 | atasu
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | hithadhoo
# Processing Record 12 of Set 3 | namatanai
# Processing Record 13 of Set 3 | mocuba
# Processing Record 14 of Set 3 | college
# Processing Record 15 of Set 3 | tuatapere
# Processing Record 16 of Set 3 | talnakh
# Processing Record 17 of Set 3 | tiznit
# Processing Record 18 of Set 3 | yellowknife
# Processing Record 19 of Set 3 | ketchikan
# No rainfall data. Setting to 0in
# Processing Record 20 of Set 3 | shestakovo
# Processing Record 21 of Set 3 | queanbeyan
# Processing Record 22 of Set 3 | siva
# Processing Record 23 of Set 3 | berlevag
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | manta
# Processing Record 26 of Set 3 | lagoa
# Processing Record 27 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 3 | la romana
# Processing Record 29 of Set 3 | chandbali
# Processing Record 30 of Set 3 | victoria
# No rainfall data. Setting to 0in
# Processing Record 31 of Set 3 | srednekolymsk
# Processing Record 32 of Set 3 | hilo
# Processing Record 33 of Set 3 | tasiilaq
# No rainfall data. Setting to 0in
# Processing Record 34 of Set 3 | bonthe
# Processing Record 35 of Set 3 | puerto escondido
# Processing Record 36 of Set 3 | rorvik
# Processing Record 37 of Set 3 | iqaluit
# Processing Record 38 of Set 3 | nanakuli
# Processing Record 39 of Set 3 | tiarei
# Processing Record 40 of Set 3 | hofn
# Processing Record 41 of Set 3 | centralia
# Processing Record 42 of Set 3 | abonnema
# Processing Record 43 of Set 3 | chapais
# No snowfall data. Setting to 0in
# Processing Record 44 of Set 3 | banyo
# Processing Record 45 of Set 3 | fengzhen
# Processing Record 46 of Set 3 | pemangkat
# City not found. Skipping...
# Processing Record 47 of Set 3 | klaksvik
# No rainfall data. Setting to 0in
# Processing Record 48 of Set 3 | viedma
# Processing Record 49 of Set 3 | zachagansk
# City not found. Skipping...
# Processing Record 50 of Set 3 | mastic beach
# Processing Record 1 of Set 4 | georgetown
# Processing Record 2 of Set 4 | enshi
# Processing Record 3 of Set 4 | abha
# Processing Record 4 of Set 4 | hobara
# Processing Record 5 of Set 4 | sunbury
# Processing Record 6 of Set 4 | san jeronimo
# No rainfall data. Setting to 0in
# Processing Record 7 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 4 | sefophe
# Processing Record 9 of Set 4 | clyde river
# No snowfall data. Setting to 0in
# Processing Record 10 of Set 4 | sterling
# Processing Record 11 of Set 4 | deputatskiy
# Processing Record 12 of Set 4 | burlington
# Processing Record 13 of Set 4 | stornoway
# City not found. Skipping...
# Processing Record 14 of Set 4 | ribeira grande
# Processing Record 15 of Set 4 | okhotsk
# Processing Record 16 of Set 4 | bulaevo
# Processing Record 17 of Set 4 | husavik
# Processing Record 18 of Set 4 | esperance
# Processing Record 19 of Set 4 | erenhot
# Processing Record 20 of Set 4 | rio grande
# Processing Record 21 of Set 4 | thompson
# Processing Record 22 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 4 | korla
# City not found. Skipping...
# Processing Record 24 of Set 4 | laguna
# Processing Record 25 of Set 4 | manuk mangkaw
# Processing Record 26 of Set 4 | nortelandia
# Processing Record 27 of Set 4 | whitehorse
# Processing Record 28 of Set 4 | sokol
# Processing Record 29 of Set 4 | leningradskiy
# Processing Record 30 of Set 4 | dali
# Processing Record 31 of Set 4 | arraial do cabo
# Processing Record 32 of Set 4 | kabalo
# Processing Record 33 of Set 4 | hamilton
# Processing Record 34 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 4 | conchas
# Processing Record 36 of Set 4 | kobojango
# City not found. Skipping...
# Processing Record 37 of Set 4 | clinton
# Processing Record 38 of Set 4 | gat
# Processing Record 39 of Set 4 | arlit
# Processing Record 40 of Set 4 | zatoka
# Processing Record 41 of Set 4 | mildura
# Processing Record 42 of Set 4 | margate
# Processing Record 43 of Set 4 | bulungu
# Processing Record 44 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 4 | richards bay
# Processing Record 46 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 4 | kodiak
# Processing Record 48 of Set 4 | picos
# Processing Record 49 of Set 4 | puerto ayacucho
# No rainfall data. Setting to 0in
# Processing Record 50 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 1 of Set 5 | provideniya
# Processing Record 2 of Set 5 | jeremie
# Processing Record 3 of Set 5 | alofi
# Processing Record 4 of Set 5 | acajutla
# Processing Record 5 of Set 5 | pajapan
# Processing Record 6 of Set 5 | lasa
# Processing Record 7 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 5 | saskylakh
# Processing Record 9 of Set 5 | moengo
# Processing Record 10 of Set 5 | samarai
# Processing Record 11 of Set 5 | luderitz
# Processing Record 12 of Set 5 | linguere
# City not found. Skipping...
# Processing Record 13 of Set 5 | camargo
# Processing Record 14 of Set 5 | uyuni
# Processing Record 15 of Set 5 | varkkallai
# Processing Record 16 of Set 5 | kapuskasing
# Processing Record 17 of Set 5 | cabedelo
# Processing Record 18 of Set 5 | edwardsville
# Processing Record 19 of Set 5 | plettenberg bay
# Processing Record 20 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 5 | bose
# Processing Record 22 of Set 5 | warrington
# Processing Record 23 of Set 5 | dunedin
# Processing Record 24 of Set 5 | vila velha
# Processing Record 25 of Set 5 | cuenca
# Processing Record 26 of Set 5 | nanortalik
# Processing Record 27 of Set 5 | alyangula
# Processing Record 28 of Set 5 | teguldet
# Processing Record 29 of Set 5 | nanchong
# Processing Record 30 of Set 5 | half moon bay
# Processing Record 31 of Set 5 | castro
# Processing Record 32 of Set 5 | necochea
# Processing Record 33 of Set 5 | poros
# Processing Record 34 of Set 5 | druzhba
# Processing Record 35 of Set 5 | xining
# Processing Record 36 of Set 5 | mayor pablo lagerenza
# Processing Record 37 of Set 5 | roma
# Processing Record 38 of Set 5 | waipawa
# Processing Record 39 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 5 | karatau
# Processing Record 41 of Set 5 | dingle
# Processing Record 42 of Set 5 | velsk
# Processing Record 43 of Set 5 | san cristobal
# Processing Record 44 of Set 5 | saint-philippe
# Processing Record 45 of Set 5 | maragogi
# Processing Record 46 of Set 5 | taltal
# Processing Record 47 of Set 5 | tual
# Processing Record 48 of Set 5 | carora
# Processing Record 49 of Set 5 | faanui
# Processing Record 50 of Set 5 | san quintin
# Processing Record 1 of Set 6 | cantagallo
# Processing Record 2 of Set 6 | douentza
# Processing Record 3 of Set 6 | sudzha
# Processing Record 4 of Set 6 | ilulissat
# Processing Record 5 of Set 6 | champerico
# Processing Record 6 of Set 6 | porto novo
# Processing Record 7 of Set 6 | yulara
# Processing Record 8 of Set 6 | saint-georges
# Processing Record 9 of Set 6 | gogrial
# City not found. Skipping...
# Processing Record 10 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 11 of Set 6 | kasempa
# Processing Record 12 of Set 6 | shinshiro
# Processing Record 13 of Set 6 | saint george
# Processing Record 14 of Set 6 | kingaroy
# Processing Record 15 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 6 | palana
# Processing Record 17 of Set 6 | dhidhdhoo
# Processing Record 18 of Set 6 | san ignacio
# Processing Record 19 of Set 6 | muros
# Processing Record 20 of Set 6 | bonfim
# Processing Record 21 of Set 6 | vicente guerrero
# Processing Record 22 of Set 6 | souillac
# Processing Record 23 of Set 6 | brae
# Processing Record 24 of Set 6 | nioro
# Processing Record 25 of Set 6 | cherskiy
# Processing Record 26 of Set 6 | babushkin
# Processing Record 27 of Set 6 | mont-de-marsan
# Processing Record 28 of Set 6 | tatvan
# Processing Record 29 of Set 6 | santa cruz del sur
# Processing Record 30 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 6 | talkha
# Processing Record 32 of Set 6 | boryslav
# Processing Record 33 of Set 6 | torbay
# Processing Record 34 of Set 6 | kruisfontein
# Processing Record 35 of Set 6 | mitsamiouli
# Processing Record 36 of Set 6 | carbonia
# Processing Record 37 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 6 | adrar
# Processing Record 39 of Set 6 | mount gambier
# Processing Record 40 of Set 6 | kaitangata
# Processing Record 41 of Set 6 | springfield
# Processing Record 42 of Set 6 | suhbaatar
# Processing Record 43 of Set 6 | lake city
# Processing Record 44 of Set 6 | teguise
# Processing Record 45 of Set 6 | sao joao da barra
# Processing Record 46 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 6 | kaihua
# Processing Record 48 of Set 6 | ostrovnoy
# Processing Record 49 of Set 6 | gurupi
# Processing Record 50 of Set 6 | airai
# Processing Record 1 of Set 7 | gouyave
# Processing Record 2 of Set 7 | matinha
# Processing Record 3 of Set 7 | okmulgee
# Processing Record 4 of Set 7 | havoysund
# Processing Record 5 of Set 7 | katherine
# Processing Record 6 of Set 7 | bengkulu
# City not found. Skipping...
# Processing Record 7 of Set 7 | belmonte
# Processing Record 8 of Set 7 | gizo
# Processing Record 9 of Set 7 | sao felix do xingu
# Processing Record 10 of Set 7 | lavrentiya
# Processing Record 11 of Set 7 | gambela
# Processing Record 12 of Set 7 | carutapera
# Processing Record 13 of Set 7 | vardo
# Processing Record 14 of Set 7 | kailua
# Processing Record 15 of Set 7 | saldanha
# Processing Record 16 of Set 7 | barranca
# Processing Record 17 of Set 7 | bonnyville
# No snowfall data. Setting to 0in
# Processing Record 18 of Set 7 | chumikan
# Processing Record 19 of Set 7 | le port
# Processing Record 20 of Set 7 | paamiut
# Processing Record 21 of Set 7 | la ronge
# No snowfall data. Setting to 0in
# Processing Record 22 of Set 7 | kuryk
# Processing Record 23 of Set 7 | port elizabeth
# Processing Record 24 of Set 7 | los llanos de aridane
# Processing Record 25 of Set 7 | halifax
# No rainfall data. Setting to 0in
# Processing Record 26 of Set 7 | otradnoye
# Processing Record 27 of Set 7 | wagar
# Processing Record 28 of Set 7 | geraldton
# Processing Record 29 of Set 7 | port macquarie
# Processing Record 30 of Set 7 | canaries
# City not found. Skipping...
# Processing Record 31 of Set 7 | okha
# Processing Record 32 of Set 7 | port said
# Processing Record 33 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 7 | zwedru
# Processing Record 35 of Set 7 | bielsk podlaski
# Processing Record 36 of Set 7 | carnarvon
# Processing Record 37 of Set 7 | bid
# City not found. Skipping...
# Processing Record 38 of Set 7 | tiksi
# Processing Record 39 of Set 7 | havelock
# Processing Record 40 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 7 | borodino
# Processing Record 42 of Set 7 | verkhnevilyuysk
# Processing Record 43 of Set 7 | luganville
# Processing Record 44 of Set 7 | ixtapa
# Processing Record 45 of Set 7 | basco
# Processing Record 46 of Set 7 | lebu
# Processing Record 47 of Set 7 | barmer
# Processing Record 48 of Set 7 | grindavik
# Processing Record 49 of Set 7 | constitucion
# Processing Record 50 of Set 7 | boguchany
# Processing Record 1 of Set 8 | diffa
# Processing Record 2 of Set 8 | codrington
# Processing Record 3 of Set 8 | dalbandin
# Processing Record 4 of Set 8 | anshun
# Processing Record 5 of Set 8 | kendari
# Processing Record 6 of Set 8 | asti
# Processing Record 7 of Set 8 | sampit
# Processing Record 8 of Set 8 | mount isa
# Processing Record 9 of Set 8 | severo-kurilsk
# Processing Record 10 of Set 8 | mineral del monte
# Processing Record 11 of Set 8 | sturgis
# Processing Record 12 of Set 8 | peniche
# Processing Record 13 of Set 8 | cidreira
# Processing Record 14 of Set 8 | chimbote
# Processing Record 15 of Set 8 | clarence town
# Processing Record 16 of Set 8 | alekseyevka
# No rainfall data. Setting to 0in
# No snowfall data. Setting to 0in
# Processing Record 17 of Set 8 | general roca
# Processing Record 18 of Set 8 | kishi
# Processing Record 19 of Set 8 | henties bay
# Processing Record 20 of Set 8 | timra
# Processing Record 21 of Set 8 | katsuura
# Processing Record 22 of Set 8 | dera baba nanak
# City not found. Skipping...
# Processing Record 23 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 8 | nazret
# Processing Record 25 of Set 8 | kuandian
# Processing Record 26 of Set 8 | allende
# Processing Record 27 of Set 8 | punta cardon
# Processing Record 28 of Set 8 | maketu
# Processing Record 29 of Set 8 | domoni
# City not found. Skipping...
# Processing Record 30 of Set 8 | mahibadhoo
# Processing Record 31 of Set 8 | patillas
# No rainfall data. Setting to 0in
# Processing Record 32 of Set 8 | solnechnyy
# Processing Record 33 of Set 8 | lethem
# Processing Record 34 of Set 8 | yerbogachen
# Processing Record 35 of Set 8 | cherkasskoye
# Processing Record 36 of Set 8 | chongwe
# Processing Record 37 of Set 8 | simpang empat
# Processing Record 38 of Set 8 | cockburn town
# Processing Record 39 of Set 8 | matara
# Processing Record 40 of Set 8 | mogadishu
# Processing Record 41 of Set 8 | conceicao do araguaia
# No rainfall data. Setting to 0in
# Processing Record 42 of Set 8 | kahului
# Processing Record 43 of Set 8 | pichayevo
# Processing Record 44 of Set 8 | sinnamary
# Processing Record 45 of Set 8 | gornyy
# Processing Record 46 of Set 8 | vysotsk
# Processing Record 47 of Set 8 | nam som
# Processing Record 48 of Set 8 | oksfjord
# No rainfall data. Setting to 0in
# Processing Record 49 of Set 8 | ardistan
# City not found. Skipping...
# Processing Record 50 of Set 8 | artyom
# Processing Record 1 of Set 9 | santa maria
# Processing Record 2 of Set 9 | mattru
# Processing Record 3 of Set 9 | ambon
# No rainfall data. Setting to 0in
# Processing Record 4 of Set 9 | moranbah
# Processing Record 5 of Set 9 | wilmington island
# Processing Record 6 of Set 9 | shimanovsk
# Processing Record 7 of Set 9 | caravelas
# Processing Record 8 of Set 9 | usinsk
# Processing Record 9 of Set 9 | willowmore
# Processing Record 10 of Set 9 | micheweni
# Processing Record 11 of Set 9 | katobu
# Processing Record 12 of Set 9 | grand gaube
# Processing Record 13 of Set 9 | vostok
# Processing Record 14 of Set 9 | canutama
# Processing Record 15 of Set 9 | acari
# Processing Record 16 of Set 9 | mujiayingzi
# Processing Record 17 of Set 9 | lerwick
# No rainfall data. Setting to 0in
# Processing Record 18 of Set 9 | obo
# Processing Record 19 of Set 9 | cayenne
# Processing Record 20 of Set 9 | oranjemund
# Processing Record 21 of Set 9 | hasaki
# Processing Record 22 of Set 9 | mansa
# Processing Record 23 of Set 9 | san luis
# Processing Record 24 of Set 9 | along
# Processing Record 25 of Set 9 | taitung
# Processing Record 26 of Set 9 | pisco
# Processing Record 27 of Set 9 | lorengau
# Processing Record 28 of Set 9 | bubaque
# Processing Record 29 of Set 9 | chegdomyn
# Processing Record 30 of Set 9 | salta
# Processing Record 31 of Set 9 | port hedland
# Processing Record 32 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 9 | flinders
# Processing Record 34 of Set 9 | ngunguru
# Processing Record 35 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 9 | saint-marc
# Processing Record 37 of Set 9 | vestbygda
# City not found. Skipping...
# Processing Record 38 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 9 | anuradhapura
# Processing Record 40 of Set 9 | auki
# Processing Record 41 of Set 9 | patacamaya
# Processing Record 42 of Set 9 | severo-yeniseyskiy
# Processing Record 43 of Set 9 | boyolangu
# Processing Record 44 of Set 9 | saint-augustin
# No rainfall data. Setting to 0in
# Processing Record 45 of Set 9 | badvel
# Processing Record 46 of Set 9 | puerto leguizamo
# Processing Record 47 of Set 9 | south lake tahoe
# Processing Record 48 of Set 9 | khorramshahr
# Processing Record 49 of Set 9 | west bay
# Processing Record 50 of Set 9 | nago
# Processing Record 1 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 2 of Set 10 | aksarka
# Processing Record 3 of Set 10 | luchegorsk
# Processing Record 4 of Set 10 | terney
# Processing Record 5 of Set 10 | yeppoon
# Processing Record 6 of Set 10 | santiago del estero
# Processing Record 7 of Set 10 | touros
# Processing Record 8 of Set 10 | brazzaville
# Processing Record 9 of Set 10 | teahupoo
# Processing Record 10 of Set 10 | iralaya
# Processing Record 11 of Set 10 | altagracia de orituco
# Processing Record 12 of Set 10 | terrak
# Processing Record 13 of Set 10 | toamasina
# No rainfall data. Setting to 0in
# Processing Record 14 of Set 10 | shkotovo-26
# City not found. Skipping...
# Processing Record 15 of Set 10 | taneatua
# City not found. Skipping...
# Processing Record 16 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 17 of Set 10 | west fargo
# Processing Record 18 of Set 10 | honiara
# Processing Record 19 of Set 10 | cabo san lucas
# Processing Record 20 of Set 10 | muzquiz
# City not found. Skipping...
# Processing Record 21 of Set 10 | sorkjosen
# City not found. Skipping...
# Processing Record 22 of Set 10 | mao
# Processing Record 23 of Set 10 | zhigansk
# Processing Record 24 of Set 10 | scarborough
# Processing Record 25 of Set 10 | vestmannaeyjar
# Processing Record 26 of Set 10 | monrovia
# Processing Record 27 of Set 10 | parksville
# Processing Record 28 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 29 of Set 10 | mahanoro
# Processing Record 30 of Set 10 | kerouane
# Processing Record 31 of Set 10 | dubbo
# Processing Record 32 of Set 10 | cortez
# Processing Record 33 of Set 10 | leeton
# Processing Record 34 of Set 10 | amahai
# Processing Record 35 of Set 10 | pevek
# Processing Record 36 of Set 10 | manaure
# Processing Record 37 of Set 10 | yarada
# Processing Record 38 of Set 10 | narsaq
# Processing Record 39 of Set 10 | sayyan
# Processing Record 40 of Set 10 | schramberg
# Processing Record 41 of Set 10 | voh
# Processing Record 42 of Set 10 | arinos
# Processing Record 43 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 44 of Set 10 | pontianak
# Processing Record 45 of Set 10 | freeport
# Processing Record 46 of Set 10 | phan thiet
# Processing Record 47 of Set 10 | lompoc
# Processing Record 48 of Set 10 | catuday
# Processing Record 49 of Set 10 | isangel
# Processing Record 50 of Set 10 | sitka
# Processing Record 1 of Set 11 | coihaique
# Processing Record 2 of Set 11 | mvuma
# Processing Record 3 of Set 11 | kaputa
# Processing Record 4 of Set 11 | broken hill
# Processing Record 5 of Set 11 | baie-comeau
# Processing Record 6 of Set 11 | pacific grove
# Processing Record 7 of Set 11 | ziway
# Processing Record 8 of Set 11 | choix
# Processing Record 9 of Set 11 | kavieng
# Processing Record 10 of Set 11 | ukiah
# Processing Record 11 of Set 11 | ploemeur
# Processing Record 12 of Set 11 | ziarat
# Processing Record 13 of Set 11 | great yarmouth
# No rainfall data. Setting to 0in
# Processing Record 14 of Set 11 | asau
# City not found. Skipping...
# Processing Record 15 of Set 11 | sibu
# No rainfall data. Setting to 0in
# Processing Record 16 of Set 11 | senneterre
# Processing Record 17 of Set 11 | antalaha
# Processing Record 18 of Set 11 | galeana
# Processing Record 19 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 11 | keti bandar
# Processing Record 21 of Set 11 | turukhansk
# Processing Record 22 of Set 11 | sorland
# Processing Record 23 of Set 11 | albacete
# Processing Record 24 of Set 11 | port hardy
# Processing Record 25 of Set 11 | vicuna
# City not found. Skipping...
# Processing Record 26 of Set 11 | katangli
# Processing Record 27 of Set 11 | marsa matruh
# Processing Record 28 of Set 11 | meulaboh
# Processing Record 29 of Set 11 | san patricio
# Processing Record 30 of Set 11 | hobyo
# Processing Record 31 of Set 11 | rawson
# Processing Record 32 of Set 11 | irituia
# Processing Record 33 of Set 11 | bijar
# Processing Record 34 of Set 11 | vanimo
# Processing Record 35 of Set 11 | bagotville
# Processing Record 36 of Set 11 | santa cruz de tenerife
# Processing Record 37 of Set 11 | camopi
# Processing Record 38 of Set 11 | kaeo
# Processing Record 39 of Set 11 | buala
# Processing Record 40 of Set 11 | kirakira
# Processing Record 41 of Set 11 | candawaga
# City not found. Skipping...
# Processing Record 42 of Set 11 | santa cruz
# Processing Record 43 of Set 11 | jalu
# Processing Record 44 of Set 11 | salinopolis
# Processing Record 45 of Set 11 | ahuimanu
# Processing Record 46 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 47 of Set 11 | fraga
# Processing Record 48 of Set 11 | davila
# Processing Record 49 of Set 11 | shimoda
# Processing Record 50 of Set 11 | victor harbor
# Processing Record 1 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 12 | nador
# Processing Record 3 of Set 12 | nuevitas
# Processing Record 4 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 12 | nemuro
# Processing Record 6 of Set 12 | praia
# No rainfall data. Setting to 0in
# Processing Record 7 of Set 12 | marawi
# Processing Record 8 of Set 12 | aranda de duero
# Processing Record 9 of Set 12 | abu samrah
# Processing Record 10 of Set 12 | faya
# Processing Record 11 of Set 12 | morwell
# Processing Record 12 of Set 12 | bilibino
# Processing Record 13 of Set 12 | evanston
# Processing Record 14 of Set 12 | dzaoudzi
# Processing Record 15 of Set 12 | saint anthony
# Processing Record 16 of Set 12 | chopda
# Processing Record 17 of Set 12 | charagua
# Processing Record 18 of Set 12 | caruray
# Processing Record 19 of Set 12 | birin
# Processing Record 20 of Set 12 | weligama
# Processing Record 21 of Set 12 | duncan
# Processing Record 22 of Set 12 | umm lajj
# Processing Record 23 of Set 12 | olafsvik
# City not found. Skipping...
# Processing Record 24 of Set 12 | mandalgovi
# Processing Record 25 of Set 12 | portobelo
# Processing Record 26 of Set 12 | wewak
# Processing Record 27 of Set 12 | lira
# Processing Record 28 of Set 12 | poya
# Processing Record 29 of Set 12 | vila
# No rainfall data. Setting to 0in
# Processing Record 30 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 31 of Set 12 | conceicao da barra
# Processing Record 32 of Set 12 | virginia
# Processing Record 33 of Set 12 | kabinda
# Processing Record 34 of Set 12 | gulabpura
# Processing Record 35 of Set 12 | fernie
# Processing Record 36 of Set 12 | kudahuvadhoo
# Processing Record 37 of Set 12 | thessalon
# No snowfall data. Setting to 0in
# Processing Record 38 of Set 12 | eidsvag
# Processing Record 39 of Set 12 | ostroleka
# Processing Record 40 of Set 12 | westport
# Processing Record 41 of Set 12 | can tho
# Processing Record 42 of Set 12 | krasnoselkup
# City not found. Skipping...
# Processing Record 43 of Set 12 | maniitsoq
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Guerrero Negro  27.97 -114.04     80.13        36          19       11.56
# 1             Fare -16.70 -151.02     81.09        77          88       19.73
# 2          Ahipara -35.17  173.16     69.01       100          71        1.01
# 3            Bluff -23.58  149.07     75.06        27           0       11.48
# 4  Bambous Virieux -20.34   57.76     69.01        77          20        5.82
# 5      Port Alfred -33.59   26.89     60.01        79          97        3.80
# 6    Mar Del Plata -46.43  -67.52     51.94        46           0       18.05
# 7     Norman Wells  65.28 -126.83     12.20        66          75        9.17
# 8        Busselton -33.64  115.35     62.01        39           0       13.33
# 9      Pangnirtung  66.15  -65.72     21.20        62          40       10.92
#
#   Weather Description  Rainfall in. (last 3 hrs.)  Snowfall in. (last 3 hrs.)  \
# 0          few clouds                        0.00                         0.0
# 1          light rain                        0.13                         0.0
# 2       broken clouds                        0.00                         0.0
# 3           clear sky                        0.00                         0.0
# 4          few clouds                        0.00                         0.0
# 5     overcast clouds                        0.00                         0.0
# 6           clear sky                        0.00                         0.0
# 7       broken clouds                        0.00                         0.0
# 8           clear sky                        0.00                         0.0
# 9    scattered clouds                        0.00                         0.0
#
#   Country                 Date
# 0      MX  2019-11-08 20:22:07
# 1      PF  2019-11-08 20:26:12
# 2      NZ  2019-11-08 20:24:14
# 3      AU  2019-11-08 20:22:12
# 4      MU  2019-11-08 20:23:56
# 5      ZA  2019-11-08 20:26:13
# 6      AR  2019-11-08 20:26:13
# 7      CA  2019-11-08 20:26:13
# 8      AU  2019-11-08 20:26:13
# 9      CA  2019-11-08 20:26:14

# %%
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 
                    'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed',
                   'Weather Description', 'Rainfall in. (last 3 hrs.)', 
                    'Snowfall in. (last 3 hrs.)']
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 0   Guerrero Negro      MX  2019-11-08 20:22:07  27.97 -114.04     80.13
# 1             Fare      PF  2019-11-08 20:26:12 -16.70 -151.02     81.09
# 2          Ahipara      NZ  2019-11-08 20:24:14 -35.17  173.16     69.01
# 3            Bluff      AU  2019-11-08 20:22:12 -23.58  149.07     75.06
# 4  Bambous Virieux      MU  2019-11-08 20:23:56 -20.34   57.76     69.01
#
#    Humidity  Cloudiness  Wind Speed Weather Description  \
# 0        36          19       11.56          few clouds
# 1        77          88       19.73          light rain
# 2       100          71        1.01       broken clouds
# 3        27           0       11.48           clear sky
# 4        77          20        5.82          few clouds
#
#    Rainfall in. (last 3 hrs.)  Snowfall in. (last 3 hrs.)
# 0                        0.00                         0.0
# 1                        0.13                         0.0
# 2                        0.00                         0.0
# 3                        0.00                         0.0
# 4                        0.00                         0.0

# %%
# Create the output file (CSV).
output_data_file = 'data/WeatherPy_challenge.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')

# %%
# Calculate number of cities with rain or snow
num_rain_cities = city_data_df[city_data_df['Rainfall in. (last 3 hrs.)'] != 0.0]['City'].count()
print(num_rain_cities)

num_snow_cities = city_data_df[city_data_df['Snowfall in. (last 3 hrs.)'] != 0.0]['City'].count()
print(num_snow_cities)
# Out:
# 52
# 13
